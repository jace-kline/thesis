# %%
# imports
import setup

# libs
from IPython.display import display
import numpy as np
import pandas as pd

# local
from build_parse import *
from metrics import *

# %%
# options for display, etc.
pd.set_option('display.max_rows', None)

# %%
prognames = [ "ndarray", "typecases", "p0", "structcases" ]
progs = [ ToyProgram(progname) for progname in prognames ]

# progs = COREUTILS_PROGS
prog_names = [ prog.get_name() for prog in progs ]

opts = BuildOptions()
dwarf_opts = BuildOptions(debug=True, strip=False, optimization=opts.optimization)
for prog in progs:
    prog.build_if_not_valid(opts)
    prog.build_if_not_valid(dwarf_opts)

# %%
metrics_groups = make_metrics()

for grp in metrics_groups:
    print(grp.get_name())
# Out:
# DATA BYTES
# FUNCTIONS
# VARNODES
# VARNODES (metatype = INT)
# VARNODES (metatype = FLOAT)
# VARNODES (metatype = POINTER)
# VARNODES (metatype = ARRAY)
# VARNODES (metatype = STRUCT)
# VARNODES (metatype = UNION)
# PRIMITIVE VARNODES
# VARNODES (decomposed) (metatype = INT)
# VARNODES (decomposed) (metatype = FLOAT)
# VARNODES (decomposed) (metatype = POINTER)
# ARRAY COMPARISONS

# %%
# compute the DWARF vs Ghidra comparisons for each program, given the build options
cmps = [ parse_compare_program(prog, opts, decompiler="ghidra") for prog in progs ]


dfs = []
for i, metrics_grp in enumerate(metrics_groups):
    df = compute_comparisons_metrics_dataframe(
        prog_names,
        cmps,
        metrics_grp
    )
    csv_out_path = DATA_DIR.joinpath("toy_{}.csv".format(i))
    df.to_csv(csv_out_path)
    dfs.append(df)

# %%
for metrics_grp, df in zip(metrics_groups, dfs):
    print("{} {} {}".format("-"*10, metrics_grp.get_name(), "-"*10))
    display(df)
# Out:
# ---------- DATA BYTES ----------
#              Ground truth data bytes  Bytes found  Bytes missed
# ndarray                         4440         4440             0
# typecases                        584          572            12
# p0                                61           61             0
# structcases                       80           67            13
# ---------- FUNCTIONS ----------
#              Ground truth functions  Functions found  Functions missed
# ndarray                           1                1                 0
# typecases                         4                4                 0
# p0                                3                3                 0
# structcases                       1                1                 0
# ---------- VARNODES ----------
#              Ground truth varnodes  Varnodes matched @ level=OVERLAP  \
# ndarray                          3                                 2
# typecases                       15                                 3
# p0                               7                                 0
# structcases                      6                                 0
#
#              Varnodes matched @ level=SUBSET  \
# ndarray                                    0
# typecases                                  2
# p0                                         0
# structcases                                3
#
#              Varnodes matched @ level=ALIGNED  Varnodes matched @ level=MATCH  \
# ndarray                                     0                               1
# typecases                                   8                               2
# p0                                          2                               5
# structcases                                 2                               1
#
#              Varnode average comparison score [0,1]
# ndarray                                    0.500000
# typecases                                  0.650000
# p0                                         0.928571
# structcases                                0.666667
# ---------- VARNODES (metatype = INT) ----------
#              Ground truth varnodes (metatype=INT)  \
# ndarray                                         0
# typecases                                       8
# p0                                              6
# structcases                                     0
#
#              Decompiler varnodes matched @ level=NO_MATCH (metatype=INT)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=OVERLAP (metatype=INT)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=SUBSET (metatype=INT)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=ALIGNED (metatype=INT)  \
# ndarray                                                      0
# typecases                                                    6
# p0                                                           2
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=MATCH (metatype=INT)  \
# ndarray                                                      0
# typecases                                                    2
# p0                                                           4
# structcases                                                  0
#
#              Varnode average compare score [0,1] (metatype=INT)
# ndarray                                                    NaN
# typecases                                             0.812500
# p0                                                    0.916667
# structcases                                                NaN
# ---------- VARNODES (metatype = FLOAT) ----------
#              Ground truth varnodes (metatype=FLOAT)  \
# ndarray                                           0
# typecases                                         0
# p0                                                0
# structcases                                       0
#
#              Decompiler varnodes matched @ level=NO_MATCH (metatype=FLOAT)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=OVERLAP (metatype=FLOAT)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=SUBSET (metatype=FLOAT)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=ALIGNED (metatype=FLOAT)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=MATCH (metatype=FLOAT)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#             Varnode average compare score [0,1] (metatype=FLOAT)
# ndarray                                                   None
# typecases                                                 None
# p0                                                        None
# structcases                                               None
# ---------- VARNODES (metatype = POINTER) ----------
#              Ground truth varnodes (metatype=POINTER)  \
# ndarray                                             0
# typecases                                           1
# p0                                                  0
# structcases                                         1
#
#              Decompiler varnodes matched @ level=NO_MATCH (metatype=POINTER)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=OVERLAP (metatype=POINTER)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=SUBSET (metatype=POINTER)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=ALIGNED (metatype=POINTER)  \
# ndarray                                                      0
# typecases                                                    1
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=MATCH (metatype=POINTER)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  1
#
#              Varnode average compare score [0,1] (metatype=POINTER)
# ndarray                                                    NaN
# typecases                                                 0.75
# p0                                                         NaN
# structcases                                               1.00
# ---------- VARNODES (metatype = ARRAY) ----------
#              Ground truth varnodes (metatype=ARRAY)  \
# ndarray                                           3
# typecases                                         2
# p0                                                1
# structcases                                       0
#
#              Decompiler varnodes matched @ level=NO_MATCH (metatype=ARRAY)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=OVERLAP (metatype=ARRAY)  \
# ndarray                                                      2
# typecases                                                    2
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=SUBSET (metatype=ARRAY)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=ALIGNED (metatype=ARRAY)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=MATCH (metatype=ARRAY)  \
# ndarray                                                      1
# typecases                                                    0
# p0                                                           1
# structcases                                                  0
#
#              Varnode average compare score [0,1] (metatype=ARRAY)
# ndarray                                                   0.50
# typecases                                                 0.25
# p0                                                        1.00
# structcases                                                NaN
# ---------- VARNODES (metatype = STRUCT) ----------
#              Ground truth varnodes (metatype=STRUCT)  \
# ndarray                                            0
# typecases                                          3
# p0                                                 0
# structcases                                        3
#
#              Decompiler varnodes matched @ level=NO_MATCH (metatype=STRUCT)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=OVERLAP (metatype=STRUCT)  \
# ndarray                                                      0
# typecases                                                    1
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=SUBSET (metatype=STRUCT)  \
# ndarray                                                      0
# typecases                                                    2
# p0                                                           0
# structcases                                                  3
#
#              Decompiler varnodes matched @ level=ALIGNED (metatype=STRUCT)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=MATCH (metatype=STRUCT)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Varnode average compare score [0,1] (metatype=STRUCT)
# ndarray                                                    NaN
# typecases                                             0.416667
# p0                                                         NaN
# structcases                                           0.500000
# ---------- VARNODES (metatype = UNION) ----------
#              Ground truth varnodes (metatype=UNION)  \
# ndarray                                           0
# typecases                                         1
# p0                                                0
# structcases                                       2
#
#              Decompiler varnodes matched @ level=NO_MATCH (metatype=UNION)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=OVERLAP (metatype=UNION)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=SUBSET (metatype=UNION)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Decompiler varnodes matched @ level=ALIGNED (metatype=UNION)  \
# ndarray                                                      0
# typecases                                                    1
# p0                                                           0
# structcases                                                  2
#
#              Decompiler varnodes matched @ level=MATCH (metatype=UNION)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Varnode average compare score [0,1] (metatype=UNION)
# ndarray                                                    NaN
# typecases                                                 0.75
# p0                                                         NaN
# structcases                                               0.75
# ---------- PRIMITIVE VARNODES ----------
#              Ground truth varnodes (decomposed)  \
# ndarray                                    1110
# typecases                                   132
# p0                                           16
# structcases                                  13
#
#              Varnodes matched @ level=NO_MATCH (decomposed)  \
# ndarray                                                   0
# typecases                                                 0
# p0                                                        0
# structcases                                               0
#
#              Varnodes matched @ level=OVERLAP (decomposed)  \
# ndarray                                               1110
# typecases                                                1
# p0                                                       0
# structcases                                              1
#
#              Varnodes matched @ level=SUBSET (decomposed)  \
# ndarray                                                 0
# typecases                                               0
# p0                                                      0
# structcases                                             0
#
#              Varnodes matched @ level=ALIGNED (decomposed)  \
# ndarray                                                  0
# typecases                                               14
# p0                                                       2
# structcases                                              8
#
#              Varnodes matched @ level=MATCH (decomposed)  \
# ndarray                                                0
# typecases                                            117
# p0                                                    14
# structcases                                            4
#
#              Varnode average comparison score [0,1] (decomposed)
# ndarray                                               0.250000
# typecases                                             0.967803
# p0                                                    0.968750
# structcases                                           0.788462
# ---------- VARNODES (decomposed) (metatype = INT) ----------
#              Ground truth varnodes (decomposed) (metatype=INT)  \
# ndarray                                                   1110
# typecases                                                  127
# p0                                                          16
# structcases                                                  7
#
#              Varnodes matched @ level=OVERLAP (decomposed) (metatype=INT)  \
# ndarray                                                   1110
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Varnodes matched @ level=SUBSET (decomposed) (metatype=INT)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Varnodes matched @ level=ALIGNED (decomposed) (metatype=INT)  \
# ndarray                                                      0
# typecases                                                   12
# p0                                                           2
# structcases                                                  7
#
#              Varnodes matched @ level=MATCH (decomposed) (metatype=INT)  \
# ndarray                                                      0
# typecases                                                  115
# p0                                                          14
# structcases                                                  0
#
#              Varnode average compare score [0,1] (decomposed) (metatype=INT)
# ndarray                                               0.250000
# typecases                                             0.976378
# p0                                                    0.968750
# structcases                                           0.750000
# ---------- VARNODES (decomposed) (metatype = FLOAT) ----------
#              Ground truth varnodes (decomposed) (metatype=FLOAT)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Varnodes matched @ level=OVERLAP (decomposed) (metatype=FLOAT)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Varnodes matched @ level=SUBSET (decomposed) (metatype=FLOAT)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Varnodes matched @ level=ALIGNED (decomposed) (metatype=FLOAT)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Varnodes matched @ level=MATCH (decomposed) (metatype=FLOAT)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#             Varnode average compare score [0,1] (decomposed) (metatype=FLOAT)
# ndarray                                                   None
# typecases                                                 None
# p0                                                        None
# structcases                                               None
# ---------- VARNODES (decomposed) (metatype = POINTER) ----------
#              Ground truth varnodes (decomposed) (metatype=POINTER)  \
# ndarray                                                      0
# typecases                                                    4
# p0                                                           0
# structcases                                                  4
#
#              Varnodes matched @ level=OVERLAP (decomposed) (metatype=POINTER)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Varnodes matched @ level=SUBSET (decomposed) (metatype=POINTER)  \
# ndarray                                                      0
# typecases                                                    0
# p0                                                           0
# structcases                                                  0
#
#              Varnodes matched @ level=ALIGNED (decomposed) (metatype=POINTER)  \
# ndarray                                                      0
# typecases                                                    2
# p0                                                           0
# structcases                                                  0
#
#              Varnodes matched @ level=MATCH (decomposed) (metatype=POINTER)  \
# ndarray                                                      0
# typecases                                                    2
# p0                                                           0
# structcases                                                  4
#
#              Varnode average compare score [0,1] (decomposed) (metatype=POINTER)
# ndarray                                                    NaN
# typecases                                                0.875
# p0                                                         NaN
# structcases                                              1.000
# ---------- ARRAY COMPARISONS ----------
#              Array comparisons  Array length (elements) average error  \
# ndarray                      2                                  274.5
# typecases                    2                                    2.0
# p0                           1                                    0.0
# structcases                  0                                    NaN
#
#              Array length (elements) average error ratio  \
# ndarray                                           0.4995
# typecases                                         0.1100
# p0                                                0.0000
# structcases                                          NaN
#
#              Array size (bytes) average error  \
# ndarray                                   4.0
# typecases                                 8.0
# p0                                        0.0
# structcases                               NaN
#
#              Array size (bytes) average error ratio  \
# ndarray                                       0.001
# typecases                                     0.110
# p0                                            0.000
# structcases                                     NaN
#
#              Array dimension match score [0,1]  \
# ndarray                                    0.0
# typecases                                  0.5
# p0                                         1.0
# structcases                                NaN
#
#              Array average element type comparison score [0,1]
# ndarray                                               0.666667
# typecases                                             1.000000
# p0                                                    1.000000
# structcases                                                NaN
